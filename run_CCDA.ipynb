# %%
from file_func import *
import glob

# %%
all_files = glob.glob(f"*nc")

for filename in all_files:
    fname = filename
    path_to_fname = '/Users/apple/Desktop/Others/Python_Codes/Cloud_Project/HSRL_DATA/Inversion_Parameters/Input/'
    path_to_utilities = '/Users/apple/Desktop/Others/Python_Codes/Cloud_Project/HSRL_DATA/Inversion_Parameters'
    path_to_calvals_ahsrl = '/Users/apple/Desktop/Others/Python_Codes/Cloud_Project/HSRL_DATA/Inversion_Parameters/HSRL_processing/hsrl/config/calvals_ahsrl.txt' 
    path_to_baseline = '/Users/apple/Desktop/Others/Python_Codes/Cloud_Project/HSRL_DATA/Inversion_Parameters/'
    fig = 'y'
    path_for_output = '/Users/apple/Desktop/Others/Python_Codes/Cirrus_Paper/2020_CCDA/Output/'

    Manila_HSRL_Ice_Cloud_Properties(fname,path_to_fname,path_to_utilities,path_to_baseline,path_to_calvals_ahsrl,fig,path_for_output)
# Out:
# Initiating CCDA for ahsrl_day_20190208T0000_20190209T0000_300s_30m.nc
# HSRL Inversion.............
# /Users/apple/Desktop/Others/Python_Codes/Cloud_Project/HSRL_DATA/Inversion_Parameters/Input/file_func.py:589: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   Signals2 = np.array(Signals2)
# HSRL Inversion Complete.............
# Calculating SNR.............
# CCDA Start.............
#  Default Thresholds in program:
#  SNR Threshold >= 2
#  Linear Depolorization Ratio >=  0.27
#  Backscatter Cross-Section >= 1e-06
#  Optical Depth Slope of Cloud > 2e-05
#  Cloud Depth >= 596 in meters
#  Total Profile Optical depth <= 2.5
# Atten_flag 3
# Gridding Cirrus Cloud Properties
# Percent Complete:  10 %
# Percent Complete:  20 %
# Percent Complete:  30 %
# ...
